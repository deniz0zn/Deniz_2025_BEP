# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hospital_billing = pd.read_csv('../Dataset/csv/Hospital Billing - Event Log.csv')
print(hospital_billing.columns)
# hospital_billing = hospital_billing.drop(columns=['msgCode', 'flagA', 'flagB', 'flagC', 'msgCount', 'msgType', 'msgCode', 'startTime'])
# Out:
# Index(['case', 'event', 'startTime', 'completeTime', 'isCancelled', 'msgType',
#        'diagnosis', 'version', 'caseType', 'actRed', 'speciality',
#        'org:resource', 'closeCode', 'blocked', 'isClosed', 'flagD',
#        'actOrange', 'flagC', 'flagB', 'flagA', 'msgCount', 'state', 'msgCode'],
#       dtype='object')

# %%
hospital_billing['event'].unique()
# Out:
# array(['NEW', 'FIN', 'RELEASE', 'CODE OK', 'BILLED', 'DELETE', 'REOPEN',
#        'CHANGE DIAGN', 'STORNO', 'REJECT', 'CODE NOK', 'SET STATUS',
#        'CHANGE END', 'MANUAL', 'JOIN-PAT', 'CODE ERROR', 'ZDBC_BEHAN',
#        'EMPTY'], dtype=object)

# %%
hospital_billing['state'].unique()
# Out:
# array(['In progress', 'Closed', 'Released', 'Billed', 'Invoice rejected',
#        'Billable', 'Empty', 'Unbillable', 'Rejected', 'Check'],
#       dtype=object)

# %% [markdown]
# ### Lengths of Process (#Events)

# %%
event_counts = hospital_billing.groupby('case').agg({'event':'count'})
low_length_cases = event_counts[event_counts['event'] < 4].reset_index()['case']
low_length_events = hospital_billing[hospital_billing['case'].isin(low_length_cases)]
low_length_events
# Out:
#         case   event                startTime             completeTime  \
# 5          B     NEW  2012/12/16 19:33:50.000  2012/12/16 19:33:50.000
# 6          B  DELETE  2013/10/19 12:37:05.000  2013/10/19 12:37:05.000
# 65         L     NEW  2012/12/23 10:33:42.000  2012/12/23 10:33:42.000
# 66         L  DELETE  2012/12/23 10:34:04.000  2012/12/23 10:34:04.000
# 119        U     NEW  2013/01/13 12:47:26.000  2013/01/13 12:47:26.000
# ...      ...     ...                      ...                      ...
# 451354  AXQE     NEW  2015/12/13 19:31:23.000  2015/12/13 19:31:23.000
# 451355  BXQE     NEW  2016/01/14 21:17:47.000  2016/01/14 21:17:47.000
# 451356  BXQE  DELETE  2016/01/14 22:00:13.000  2016/01/14 22:00:13.000
# 451357  CXQE     NEW  2016/01/11 19:40:47.000  2016/01/11 19:40:47.000
# 451358  DXQE     NEW  2016/01/13 22:48:13.000  2016/01/13 22:48:13.000
#
#         isCancelled msgType diagnosis version caseType actRed  ... blocked  \
# 5             False     NaN         B     NaN        A    NaN  ...   False
# 6              True     NaN         B     NaN        A    NaN  ...   False
# 65            False     NaN       NaN     NaN        B    NaN  ...   False
# 66             True     NaN       NaN     NaN        B    NaN  ...   False
# 119           False     NaN       NaN     NaN        C    NaN  ...   False
# ...             ...     ...       ...     ...      ...    ...  ...     ...
# 451354        False     NaN        OM     NaN        A    NaN  ...   False
# 451355        False     NaN       NaN     NaN        B    NaN  ...   False
# 451356         True     NaN       NaN     NaN        B    NaN  ...   False
# 451357        False     NaN        LL     NaN        A    NaN  ...   False
# 451358        False     NaN       NaN     NaN        I    NaN  ...   False
#
#        isClosed  flagD  actOrange  flagC  flagB  flagA msgCount        state  \
# 5         False  False        NaN    NaN  False  False      NaN  In progress
# 6         False  False        NaN    NaN  False  False      NaN  In progress
# 65        False  False        NaN    NaN  False  False      NaN  In progress
# 66        False  False        NaN    NaN  False  False      NaN  In progress
# 119        True  False        NaN    NaN  False  False      NaN  In progress
# ...         ...    ...        ...    ...    ...    ...      ...          ...
# 451354    False  False        NaN    NaN  False  False      NaN  In progress
# 451355    False  False        NaN    NaN  False  False      NaN  In progress
# 451356    False  False        NaN    NaN  False  False      NaN  In progress
# 451357    False  False        NaN    NaN  False  False      NaN  In progress
# 451358     True  False        NaN    NaN  False  False      NaN  In progress
#
#         msgCode
# 5           NaN
# 6           NaN
# 65          NaN
# 66          NaN
# 119         NaN
# ...         ...
# 451354      NaN
# 451355      NaN
# 451356      NaN
# 451357      NaN
# 451358      NaN
#
# [44957 rows x 23 columns]

# %%
case_counts_by_event = event_counts.reset_index().groupby('event').agg({'case':'count'})
case_counts_by_event
# event_counts[event_counts['event'] == 117]
# Out:
#         case
# event
# 1      22372
# 2       8375
# 3       1945
# 4        801
# 5      22902
# 6      35154
# 7       3376
# 8        919
# 9       1126
# 10      1372
# 11       453
# 12       239
# 13       443
# 14       183
# 15        90
# 16        60
# 17        50
# 18        37
# 19        25
# 20        16
# 21        13
# 22        15
# 23         6
# 24         3
# 25         4
# 26         1
# 27         3
# 28         1
# 29         1
# 31         1
# 32         1
# 33         1
# 34         2
# 40         1
# 41         1
# 42         1
# 49         1
# 52         1
# 117        1
# 157        1
# 176        1
# 217        1

# %%
Q1 = event_counts['event'].quantile(0.25)
Q3 = event_counts['event'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

filtered_case_counts = event_counts[(event_counts['event'] >= lower_bound) & (event_counts['event'] <= upper_bound)]

plt.figure(figsize=(8, 5))
plt.hist(filtered_case_counts['event'], bins=range(1, filtered_case_counts['event'].max() + 2), edgecolor='black')
plt.xlabel('Number of Events per Case')
plt.ylabel('Frequency')
plt.title('Distribution of Number of Events per Case (Outliers Removed)')
plt.xticks(range(1, filtered_case_counts['event'].max() + 1))
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
hospital_billing['completeTime'] = pd.to_datetime(hospital_billing['completeTime'])

# Sort by case and completeTime to ensure the last event is correctly identified
hospital_billing = hospital_billing.sort_values(by=['case', 'completeTime'])

# Group by 'case' and get the last event in each group
grouped_hospital = hospital_billing.groupby('case').last().reset_index().rename(columns={'event': 'last_event'})
print(f'Number of cases: {len(grouped_hospital)}')
grouped_hospital.head(25)
# Out:
# Number of cases: 99999
#     case last_event                startTime        completeTime  isCancelled  \
# 0      A     BILLED  2013/12/19 03:44:31.000 2013-12-19 03:44:31        False
# 1     AA     BILLED  2013/07/07 19:21:27.000 2013-07-07 19:21:27        False
# 2    AAA        NEW  2013/01/26 22:56:11.000 2013-01-26 22:56:11        False
# 3   AAAA     BILLED  2013/10/24 04:16:56.000 2013-10-24 04:16:56        False
# 4   AAAB     BILLED  2014/03/16 22:08:48.000 2014-03-16 22:08:48        False
# 5   AAAC     BILLED  2014/10/08 11:18:43.000 2014-10-08 11:18:43        False
# 6   AAAD        NEW  2014/12/10 22:49:28.000 2014-12-10 22:49:28        False
# 7   AAAE        FIN  2015/12/01 20:06:35.000 2015-12-01 20:06:35        False
# 8    AAB        NEW  2013/01/03 22:55:39.000 2013-01-03 22:55:39        False
# 9   AABA     BILLED  2013/10/31 11:30:59.000 2013-10-31 11:30:59        False
# 10  AABB        NEW  2013/12/24 22:47:21.000 2013-12-24 22:47:21        False
# 11  AABC     BILLED  2014/10/29 02:33:09.000 2014-10-29 02:33:09        False
# 12  AABD     BILLED  2015/08/18 22:23:38.000 2015-08-18 22:23:38        False
# 13  AABE     BILLED  2015/12/24 20:45:44.000 2015-12-24 20:45:44        False
# 14   AAC     BILLED  2013/07/13 23:58:02.000 2013-07-13 23:58:02        False
# 15  AACA     BILLED  2013/12/06 18:55:51.000 2013-12-06 18:55:51        False
# 16  AACB     BILLED  2015/01/29 11:40:09.000 2015-01-29 11:40:09        False
# 17  AACC     BILLED  2014/10/23 22:02:56.000 2014-10-23 22:02:56        False
# 18  AACD     BILLED  2015/10/13 21:10:10.000 2015-10-13 21:10:10        False
# 19  AACE        NEW  2015/08/13 08:37:00.000 2015-08-13 08:37:00        False
# 20   AAD        NEW  2013/01/15 23:04:19.000 2013-01-15 23:04:19        False
# 21  AADA        FIN  2014/01/07 21:40:06.000 2014-01-07 21:40:06        False
# 22  AADB     BILLED  2015/08/28 12:55:21.000 2015-08-28 12:55:21        False
# 23  AADC     BILLED  2014/11/02 21:27:41.000 2014-11-02 21:27:41        False
# 24  AADD     BILLED  2015/09/10 13:37:42.000 2015-09-10 13:37:42        False
#
#    msgType diagnosis version caseType actRed  ... blocked isClosed  flagD  \
# 0     None         A       A        A  False  ...   False     True   True
# 1     None        CA       C        B  False  ...   False     True   True
# 2     None      None    None        C   None  ...   False     True  False
# 3     None        JA       D        B  False  ...   False     True   True
# 4     None         Z       A        B  False  ...   False     True   True
# 5     None        OB       F        B  False  ...   False     True   True
# 6     None      None    None        I   None  ...   False     True  False
# 7     None         T    None        A   None  ...   False     True   True
# 8     None      None    None        C   None  ...   False     True  False
# 9     None        AI       D        B  False  ...   False     True   True
# 10    None      None    None        I   None  ...   False     True  False
# 11    None        QB       F        A  False  ...   False     True   True
# 12    None       TNA       E        B  False  ...   False     True   True
# 13    None        VH       E        A  False  ...   False     True   True
# 14    None        IG       C        D  False  ...   False     True   True
# 15    None        NE       D        B  False  ...   False     True   True
# 16    None        ZG       E        A  False  ...   False     True   True
# 17    None        WC       F        B  False  ...   False     True   True
# 18    None        AH       E        A  False  ...   False     True   True
# 19    None      None    None        I   None  ...   False     True  False
# 20    None      None    None        C   None  ...   False     True  False
# 21    None        TJ    None        A   None  ...   False     True   True
# 22    None        JG       E        A   True  ...   False     True   True
# 23    None         Z       F        B  False  ...   False     True   True
# 24    None        NH       E        B  False  ...   False     True   True
#
#     actOrange  flagC  flagB  flagA msgCount        state  msgCode
# 0       False  False  False  False      0.0       Billed     None
# 1       False  False  False  False      0.0       Billed     None
# 2        None   None  False  False      NaN  In progress     None
# 3       False  False  False  False      0.0       Billed     None
# 4       False  False  False  False      0.0       Billed     None
# 5       False  False  False  False      0.0       Billed     None
# 6        None   None  False  False      NaN  In progress     None
# 7        None   None  False  False      NaN        Empty     None
# 8        None   None  False  False      NaN  In progress     None
# 9       False  False  False  False      0.0       Billed     None
# 10       None   None  False  False      NaN  In progress     None
# 11      False  False  False  False      0.0       Billed     None
# 12      False  False  False  False      0.0       Billed     None
# 13      False  False  False  False      0.0       Billed     None
# 14      False  False  False  False      0.0       Billed     None
# 15      False  False  False  False      0.0       Billed     None
# 16      False  False  False  False      0.0       Billed     None
# 17      False  False  False  False      0.0       Billed     None
# 18      False  False  False  False      0.0       Billed     None
# 19       None   None  False  False      NaN  In progress     None
# 20       None   None  False  False      NaN  In progress     None
# 21       None   None  False  False      NaN        Empty     None
# 22      False   True  False  False      0.0       Billed     None
# 23      False  False  False  False      0.0       Billed     None
# 24      False  False  False  False      0.0       Billed     None
#
# [25 rows x 23 columns]

# %% [markdown]
# ### isCancelled

# %%
not_cancelled = grouped_hospital[grouped_hospital['isCancelled'] !=True]
print('Number of cases that are not cancelled: ', len(not_cancelled))
print(not_cancelled.head())

cancelled_and_notDelete = grouped_hospital[(grouped_hospital['isCancelled']) & (grouped_hospital['last_event'] != 'DELETE')]
print('\nNumber of cases that are Cancelled but the last event is not DELETE: ',len(cancelled_and_notDelete), '\nhead of the table:')
print(cancelled_and_notDelete)

cancelled_and_Delete = grouped_hospital[(grouped_hospital['isCancelled']) & (grouped_hospital['last_event'] == 'DELETE')]
print('\nNumber of cases that are Cancelled and the last event is DELETE: ', len(cancelled_and_Delete), '\nhead of the table:')
print(cancelled_and_Delete.head())


notCancelled_delete = grouped_hospital[(grouped_hospital['isCancelled'] != True) & (grouped_hospital['last_event'] == 'DELETE')]
print('\nNumber of cases that are not Cancelled and the last event is DELETE: ', len(notCancelled_delete), '\nhead of the table:')
print(notCancelled_delete.head())
# Out:
# Number of cases that are not cancelled:  91777
#    case last_event                startTime        completeTime  isCancelled  \
# 0     A     BILLED  2013/12/19 03:44:31.000 2013-12-19 03:44:31        False
# 1    AA     BILLED  2013/07/07 19:21:27.000 2013-07-07 19:21:27        False
# 2   AAA        NEW  2013/01/26 22:56:11.000 2013-01-26 22:56:11        False
# 3  AAAA     BILLED  2013/10/24 04:16:56.000 2013-10-24 04:16:56        False
# 4  AAAB     BILLED  2014/03/16 22:08:48.000 2014-03-16 22:08:48        False
#
#   msgType diagnosis version caseType actRed  ... blocked isClosed  flagD  \
# 0    None         A       A        A  False  ...   False     True   True
# 1    None        CA       C        B  False  ...   False     True   True
# 2    None      None    None        C   None  ...   False     True  False
# 3    None        JA       D        B  False  ...   False     True   True
# 4    None         Z       A        B  False  ...   False     True   True
#
#    actOrange  flagC  flagB  flagA msgCount        state  msgCode
# 0      False  False  False  False      0.0       Billed     None
# 1      False  False  False  False      0.0       Billed     None
# 2       None   None  False  False      NaN  In progress     None
# 3      False  False  False  False      0.0       Billed     None
# 4      False  False  False  False      0.0       Billed     None
#
# [5 rows x 23 columns]
#
# Number of cases that are Cancelled but the last event is not DELETE:  7
# head of the table:
#        case last_event                startTime        completeTime  \
# 5669   BMHB   JOIN-PAT  2015/09/20 10:40:18.000 2015-09-20 10:40:18
# 13590  DNVA     MANUAL  2014/05/05 09:33:49.000 2014-05-05 09:33:49
# 39680   KIF   JOIN-PAT  2014/09/09 13:41:28.000 2014-09-09 13:41:28
# 90104  XLCA   JOIN-PAT  2013/08/04 10:21:54.000 2013-08-04 10:21:54
# 90239   XMA   JOIN-PAT  2013/01/26 10:25:14.000 2013-01-26 10:25:14
# 92672  YCLA   JOIN-PAT  2014/02/23 13:22:47.000 2014-02-23 13:22:47
# 99632  ZXMA   JOIN-PAT  2014/09/04 10:52:36.000 2014-09-04 10:52:36
#
#        isCancelled msgType diagnosis version caseType actRed  ... blocked  \
# 5669          True    None        PD    None        C   None  ...   False
# 13590         True    None        PD    None        C   None  ...   False
# 39680         True    None         H    None        B   None  ...   False
# 90104         True    None        FV    None        B   None  ...   False
# 90239         True    None        WE    None        A   None  ...   False
# 92672         True    None        IC    None        A   None  ...   False
# 99632         True    None      None    None        I   None  ...   False
#
#       isClosed  flagD  actOrange  flagC  flagB  flagA msgCount        state  \
# 5669     False  False       None   None  False  False      NaN  In progress
# 13590    False  False       None   None  False  False      NaN  In progress
# 39680    False   True       None   None  False  False      NaN  In progress
# 90104    False  False       None   None  False  False      NaN  In progress
# 90239    False  False       None   None  False  False      NaN  In progress
# 92672    False  False       None   None  False  False      NaN  In progress
# 99632     True  False       None   None  False  False      NaN     Billable
#
#        msgCode
# 5669      None
# 13590     None
# 39680     None
# 90104     None
# 90239     None
# 92672     None
# 99632     None
#
# [7 rows x 23 columns]
#
# Number of cases that are Cancelled and the last event is DELETE:  8215
# head of the table:
#     case last_event                startTime        completeTime  isCancelled  \
# 32   AAF     DELETE  2013/04/15 09:43:06.000 2013-04-15 09:43:06         True
# 37  AAFE     DELETE  2015/08/26 07:38:30.000 2015-08-26 07:38:30         True
# 41  AAGC     DELETE  2014/09/24 13:47:03.000 2014-09-24 13:47:03         True
# 67  AAKE     DELETE  2015/12/14 09:02:56.000 2015-12-14 09:02:56         True
# 72  AALD     DELETE  2015/04/20 16:58:45.000 2015-04-20 16:58:45         True
#
#    msgType diagnosis version caseType actRed  ... blocked isClosed  flagD  \
# 32    None        OE    None        A   None  ...   False    False  False
# 37    None      None    None        B   None  ...   False    False  False
# 41    None        IC    None        A   None  ...   False    False  False
# 67    None        SB    None        A   None  ...   False    False  False
# 72    None         W    None        A   None  ...   False    False  False
#
#     actOrange  flagC  flagB  flagA msgCount        state  msgCode
# 32       None   None  False  False      NaN  In progress     None
# 37       None   None  False  False      NaN  In progress     None
# 41       None   None  False  False      NaN  In progress     None
# 67       None   None  False  False      NaN  In progress     None
# 72       None   None  False  False      NaN  In progress     None
#
# [5 rows x 23 columns]
#
# Number of cases that are not Cancelled and the last event is DELETE:  0
# head of the table:
# Empty DataFrame
# Columns: [case, last_event, startTime, completeTime, isCancelled, msgType, diagnosis, version, caseType, actRed, speciality, org:resource, closeCode, blocked, isClosed, flagD, actOrange, flagC, flagB, flagA, msgCount, state, msgCode]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ### Blocked

# %%
blocked = grouped_hospital[grouped_hospital['blocked']]
blocked[['case', 'last_event', 'isCancelled', 'diagnosis', 'version', 'caseType', 'blocked', 'state']]
# Out:
#        case  last_event  isCancelled diagnosis version caseType  blocked  \
# 5342   BKCA      DELETE         True        DA       D        A     True
# 18663  EWCE      MANUAL        False        NL       E        A     True
# 27098  HBDD      MANUAL        False        TN       E        B     True
# 33853  IUUB      MANUAL        False        BR       E        B     True
# 39247  KFGE     CODE OK        False        XA       E        B     True
# 40277  KMFE     CODE OK        False        KE       E        B     True
# 41441  KUCC     CODE OK        False        OB       E        A     True
# 41567  KUYD     CODE OK        False       LKA       E        A     True
# 49425  MWBE     CODE OK        False        WD       E        B     True
# 56317  OQQD  SET STATUS        False        LE       E        B     True
# 59445   PLV      DELETE         True        FA       B        A     True
# 59876  POSB      MANUAL        False        LE       E        A     True
# 68291  RTPB     CODE OK        False        OB       E        A     True
# 70691  SJVD     CODE OK        False         Z       E        B     True
# 78088   UHW     CODE OK        False        YA       E        A     True
# 81896  VHOE     CODE OK        False        XA       E        A     True
# 92606  YCAA      DELETE         True        QG       D        A     True
# 97566  ZJNA      MANUAL        False        OB       A        B     True
#
#             state
# 5342       Closed
# 18663      Billed
# 27098      Billed
# 33853      Billed
# 39247      Billed
# 40277      Billed
# 41441      Billed
# 41567      Billed
# 49425      Billed
# 56317  Unbillable
# 59445      Closed
# 59876      Billed
# 68291      Billed
# 70691    Released
# 78088      Billed
# 81896      Billed
# 92606      Closed
# 97566      Billed

# %% [markdown]
# ### actOrange

# %%
actOrange = grouped_hospital[grouped_hospital.fillna(False)['actOrange']]
print(actOrange.groupby('state').agg({'case': 'count'}))
grouped_hospital
# Out:
#              case
# state
# Billed        120
# Empty           1
# In progress    11
# Released        2
# Unbillable      1
# /tmp/ipykernel_257/329655348.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   actOrange = grouped_hospital[grouped_hospital.fillna(False)['actOrange']]
#        case last_event                startTime        completeTime  \
# 0         A     BILLED  2013/12/19 03:44:31.000 2013-12-19 03:44:31
# 1        AA     BILLED  2013/07/07 19:21:27.000 2013-07-07 19:21:27
# 2       AAA        NEW  2013/01/26 22:56:11.000 2013-01-26 22:56:11
# 3      AAAA     BILLED  2013/10/24 04:16:56.000 2013-10-24 04:16:56
# 4      AAAB     BILLED  2014/03/16 22:08:48.000 2014-03-16 22:08:48
# ...     ...        ...                      ...                 ...
# 99994   ZZZ     BILLED  2013/10/20 04:16:55.000 2013-10-20 04:16:55
# 99995  ZZZA     DELETE  2014/01/12 11:22:26.000 2014-01-12 11:22:26
# 99996  ZZZB     DELETE  2014/07/01 14:30:41.000 2014-07-01 14:30:41
# 99997  ZZZC        NEW  2015/01/17 22:49:28.000 2015-01-17 22:49:28
# 99998  ZZZD     BILLED  2015/07/20 22:34:51.000 2015-07-20 22:34:51
#
#        isCancelled msgType diagnosis version caseType actRed  ... blocked  \
# 0            False    None         A       A        A  False  ...   False
# 1            False    None        CA       C        B  False  ...   False
# 2            False    None      None    None        C   None  ...   False
# 3            False    None        JA       D        B  False  ...   False
# 4            False    None         Z       A        B  False  ...   False
# ...            ...     ...       ...     ...      ...    ...  ...     ...
# 99994        False    None        EY       D        B  False  ...   False
# 99995         True    None      None    None        B   None  ...   False
# 99996         True    None        BC    None        D   None  ...   False
# 99997        False    None      None    None        I   None  ...   False
# 99998        False    None        UE       E        A  False  ...   False
#
#       isClosed  flagD  actOrange  flagC  flagB  flagA msgCount        state  \
# 0         True   True      False  False  False  False      0.0       Billed
# 1         True   True      False  False  False  False      0.0       Billed
# 2         True  False       None   None  False  False      NaN  In progress
# 3         True   True      False  False  False  False      0.0       Billed
# 4         True   True      False  False  False  False      0.0       Billed
# ...        ...    ...        ...    ...    ...    ...      ...          ...
# 99994     True   True      False  False  False  False      0.0       Billed
# 99995    False  False       None   None  False  False      NaN  In progress
# 99996    False   True       None   None  False  False      NaN  In progress
# 99997     True  False       None   None  False  False      NaN  In progress
# 99998     True   True      False  False  False  False      0.0       Billed
#
#        msgCode
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None
# ...        ...
# 99994     None
# 99995     None
# 99996     None
# 99997     None
# 99998     None
#
# [99999 rows x 23 columns]

# %% [markdown]
# ### Close Codes:

# %%
# Group by last event's  'closeCode', 'last_event', 'state' and get total number of cases for each combination of these.
close_codes =  grouped_hospital.groupby(['closeCode', 'last_event', 'state']).agg('count').reset_index().sort_values(by='case', ascending=False)
sum_cases = close_codes['case'].sum()
print(f'\nTotal Number of cases in close_codes: {sum_cases}\nclose_codes')
close_codes
# Out:
# Total Number of cases in close_codes: 71014
# close_codes
#     closeCode last_event        state   case  startTime  completeTime  \
# 33          C     BILLED       Billed  24325      24325         24325
# 0           A     BILLED       Billed  15920      15920         15920
# 17          B     BILLED       Billed   8050       8050          8050
# 71          E     BILLED       Billed   4458       4458          4458
# 111         H        FIN        Empty   3563       3563          3563
# ..        ...        ...          ...    ...        ...           ...
# 98          G    CODE OK     Billable      1          1             1
# 16         AA     BILLED       Billed      1          1             1
# 137         L   CODE NOK       Billed      1          1             1
# 172         Q     DELETE        Empty      1          1             1
# 203         Z     DELETE  In progress      1          1             1
#
#      isCancelled  msgType  diagnosis  version  ...  org:resource  blocked  \
# 33         24325      236      24309    24325  ...         24325    24325
# 0          15920       60      15902    15920  ...         15920    15920
# 17          8050      125       8050     8050  ...          8050     8050
# 71          4458      109       4448     4458  ...          4458     4458
# 111         3563        3       3560        6  ...          3563     3563
# ..           ...      ...        ...      ...  ...           ...      ...
# 98             1        0          1        1  ...             1        1
# 16             1        0          1        0  ...             1        1
# 137            1        1          1        1  ...             1        1
# 172            1        0          1        0  ...             1        1
# 203            1        0          1        1  ...             1        1
#
#      isClosed  flagD  actOrange  flagC  flagB  flagA  msgCount  msgCode
# 33      24325  24325      24325  24325  24325  24325     24325      236
# 0       15920  15920      15920  15920  15920  15920     15920       60
# 17       8050   8050       8050   8050   8050   8050      8050      125
# 71       4458   4458       4458   4458   4458   4458      4458      109
# 111      3563   3563          6      6   3563   3563         6        3
# ..        ...    ...        ...    ...    ...    ...       ...      ...
# 98          1      1          1      1      1      1         1        0
# 16          1      1          0      0      1      1         0        0
# 137         1      1          1      1      1      1         1        1
# 172         1      1          0      0      1      1         0        0
# 203         1      1          1      1      1      1         1        0
#
# [204 rows x 23 columns]

# %% [markdown]
# ### Last Event and State:

# %%
last_event_state_grouped = grouped_hospital.groupby(['last_event','state']).agg({'case': 'count'}).reset_index().sort_values(by='case', ascending=False)
sum_cases = last_event_state_grouped['case'].sum()
last_event_state_grouped['ratio'] = last_event_state_grouped['case']/sum_cases
print(f'\nTotal Number of cases in last_event_state_grouped: {sum_cases}\n:')
last_event_state_grouped
# Out:
# Total Number of cases in last_event_state_grouped: 99999
# :
#       last_event        state   case     ratio
# 0         BILLED       Billed  63498  0.634986
# 27           NEW  In progress  22406  0.224062
# 13        DELETE  In progress   7424  0.074241
# 19           FIN        Empty   3563  0.035630
# 7        CODE OK       Billed    832  0.008320
# 31    SET STATUS   Unbillable    458  0.004580
# 17         EMPTY        Empty    444  0.004440
# 15        DELETE     Released    281  0.002810
# 11        DELETE       Closed    228  0.002280
# 9         DELETE     Billable    214  0.002140
# 30    SET STATUS        Empty    142  0.001420
# 8        CODE OK     Released    115  0.001150
# 29       RELEASE     Released    107  0.001070
# 12        DELETE        Empty     63  0.000630
# 23        MANUAL       Billed     57  0.000570
# 18           FIN       Closed     48  0.000480
# 20      JOIN-PAT     Billable     30  0.000300
# 1   CHANGE DIAGN  In progress     19  0.000190
# 26        MANUAL   Unbillable     18  0.000180
# 21      JOIN-PAT       Billed     12  0.000120
# 4       CODE NOK     Released     11  0.000110
# 25        MANUAL     Released      9  0.000090
# 22      JOIN-PAT  In progress      5  0.000050
# 28        REJECT     Billable      4  0.000040
# 10        DELETE        Check      3  0.000030
# 16        DELETE   Unbillable      1  0.000010
# 24        MANUAL  In progress      1  0.000010
# 14        DELETE     Rejected      1  0.000010
# 6        CODE OK     Billable      1  0.000010
# 5       CODE NOK   Unbillable      1  0.000010
# 3       CODE NOK        Empty      1  0.000010
# 2       CODE NOK       Billed      1  0.000010
# 32        STORNO     Billable      1  0.000010

# %% [markdown]
# ### State of Last Event:

# %%
# Group by 'state' (last event's state in the case) and calculate the total number of cases
ratio_of_state = grouped_hospital.groupby(['state']).agg({'case': 'count'}).reset_index().sort_values(by='case', ascending=False)
sum_cases = ratio_of_state['case'].sum()
print(f'\nTotal Number of cases in ratio_of_state: {sum_cases}\nratio_of_state:')
ratio_of_state['ratio'] = ratio_of_state['case']/ratio_of_state['case'].sum()
ratio_of_state
# Out:
# Total Number of cases in ratio_of_state: 99999
# ratio_of_state:
#          state   case     ratio
# 1       Billed  64400  0.644006
# 5  In progress  29855  0.298553
# 4        Empty   4213  0.042130
# 7     Released    523  0.005230
# 8   Unbillable    478  0.004780
# 3       Closed    276  0.002760
# 0     Billable    250  0.002500
# 2        Check      3  0.000030
# 6     Rejected      1  0.000010

# %% [markdown]
# ### Last event for each case

# %%
last_event_df = grouped_hospital.groupby(['last_event']).count().sort_values('case',ascending=False)
last_event_df['ratio'] = last_event_df['case'] / last_event_df['case'].sum()
last_event_df.reset_index().plot(kind='bar', x='last_event', y='ratio')
last_event_df[['case', 'ratio']]
# Out:
#                case     ratio
# last_event
# BILLED        63498  0.634986
# NEW           22406  0.224062
# DELETE         8215  0.082151
# FIN            3611  0.036110
# CODE OK         948  0.009480
# SET STATUS      600  0.006000
# EMPTY           444  0.004440
# RELEASE         107  0.001070
# MANUAL           85  0.000850
# JOIN-PAT         47  0.000470
# CHANGE DIAGN     19  0.000190
# CODE NOK         14  0.000140
# REJECT            4  0.000040
# STORNO            1  0.000010

# %% [markdown]
# ### Case Type

# %%
case_type = hospital_billing.groupby(['case','caseType'])
case_type.size()
# Out:
# case  caseType
# A     A           5
# AA    B           6
# AAA   C           1
# AAAA  B           6
# AAAB  B           6
#                  ..
# ZZZ   B           6
# ZZZA  B           2
# ZZZB  D           3
# ZZZC  I           1
# ZZZD  A           5
# Length: 101494, dtype: int64

# %% [markdown]
# ### Gaps or Delays
# --> Start time = Complete time

# %%
hospital_billing[hospital_billing['startTime'] != hospital_billing['completeTime']]
# Out:
# Empty DataFrame
# Columns: [case, event, startTime, completeTime, isCancelled, msgType, diagnosis, version, caseType, actRed, speciality, org:resource, closeCode, blocked, isClosed, flagD, actOrange, flagC, flagB, flagA, msgCount, state, msgCode]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# ### Blocked Cases

# %%
blocked = hospital_billing[hospital_billing['blocked']]
blocked
# Out:
#         case    event                startTime        completeTime  \
# 96661   BKCA      NEW  2013/06/24 05:45:07.000 2013-06-24 05:45:07
# 96662   BKCA      FIN  2013/08/23 06:23:36.000 2013-08-23 06:23:36
# 96663   BKCA  RELEASE  2013/08/23 07:51:56.000 2013-08-23 07:51:56
# 96664   BKCA  CODE OK  2013/08/30 02:30:49.000 2013-08-30 02:30:49
# 96665   BKCA   DELETE  2013/10/31 14:23:25.000 2013-10-31 14:23:25
# ...      ...      ...                      ...                 ...
# 131690  ZJNA  CODE OK  2013/11/02 09:32:38.000 2013-11-02 09:32:38
# 131691  ZJNA   BILLED  2013/11/14 12:25:32.000 2013-11-14 12:25:32
# 131692  ZJNA   MANUAL  2014/03/26 12:51:50.000 2014-03-26 12:51:50
# 131693  ZJNA  CODE OK  2014/03/26 12:57:25.000 2014-03-26 12:57:25
# 131694  ZJNA   MANUAL  2014/03/26 13:15:02.000 2014-03-26 13:15:02
#
#         isCancelled msgType diagnosis version caseType actRed  ... blocked  \
# 96661         False     NaN        DA     NaN        A    NaN  ...    True
# 96662         False     NaN        DA     NaN        A    NaN  ...    True
# 96663         False     NaN        DA     NaN        A    NaN  ...    True
# 96664         False     NaN        DA       D        A  False  ...    True
# 96665          True     NaN        DA       D        A  False  ...    True
# ...             ...     ...       ...     ...      ...    ...  ...     ...
# 131690        False       W        OB       D        B  False  ...    True
# 131691        False       W        OB       D        B  False  ...    True
# 131692        False       W        OB       D        B  False  ...    True
# 131693        False       W        OB       A        B  False  ...    True
# 131694        False       W        OB       A        B  False  ...    True
#
#        isClosed flagD  actOrange  flagC  flagB  flagA msgCount        state  \
# 96661      True  True        NaN    NaN  False  False      NaN  In progress
# 96662      True  True        NaN    NaN  False  False      NaN       Closed
# 96663      True  True        NaN    NaN  False  False      NaN     Released
# 96664      True  True      False  False  False  False      0.0     Released
# 96665      True  True      False  False  False  False      0.0       Closed
# ...         ...   ...        ...    ...    ...    ...      ...          ...
# 131690     True  True      False  False  False  False      0.0     Released
# 131691     True  True      False  False  False  False      0.0       Billed
# 131692     True  True      False  False  False  False      0.0     Released
# 131693     True  True      False  False  False  False      0.0     Released
# 131694     True  True      False  False  False  False      0.0       Billed
#
#         msgCode
# 96661       NaN
# 96662       NaN
# 96663       NaN
# 96664       NaN
# 96665       NaN
# ...         ...
# 131690        A
# 131691        A
# 131692        A
# 131693        A
# 131694        A
#
# [147 rows x 23 columns]
